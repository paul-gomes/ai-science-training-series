# %%
import pandas as pd
from tabulate import tabulate
data = pd.read_csv('result.csv')
print(tabulate(data, headers = 'keys'))
# Out:
#       parallel thread    prefetch buffer size    mean img/s    std deviation
# --  -----------------  ----------------------  ------------  ---------------
#  0                  2                       1        191.42           330.55
#  1                  4                       1        259.45           302.35
#  2                  8                       1        355.18           272.06
#  3                 16                       1        304.39           291.54
#  4                 32                       1        368.93           339.57
#  5                 64                       1        568.87           291.18
#  6                128                       1        749.73           332.07
#  7                256                       1        510.66           319.57
#  8                  2                       2        300.38           507.7
#  9                  4                       2         60.17            89.12
# ...
